# %% [markdown]
# ## Rosalind Project Question 2
# - https://rosalind.info/problems/rna/

# %%
example = '...'

# %% [markdown]
# #### Approach 1:

# %%
def DNA_to_RNA(DNA):
    RNA = ''
    for i in DNA:
        if i == 'T':
            RNA += 'U'
        else:
            RNA += i
    return RNA

DNA_to_RNA(example)
# Out:
# '...'

# %% [markdown]
# #### Approach 2:

# %%
print(example.replace('T','U'))
# Out:
# ...
